# %% [markdown]
# Libraries - OpenCV , pytesseract

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'' ###where .exe of tesseract is saved

# %%
import cv2
img = cv2.imread('')
cv2.imshow()
cv2.waitkey(0)
cv2.destroyAllWindows()

# %%
text = pytesseract.image_to_string(img)
print(text)
