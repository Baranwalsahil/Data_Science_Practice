# %% [markdown]
# Dropping Constant Features

# %%
import pandas as pd

data = pd.DataFrame({"A" : [1,2,4,1,2,4],
                     "B" : [4,5,6,7,8,9],
                     "C" : [0,0,0,0,0,0],
                     "D" : [1,1,1,1,1,1]})

# %%
data
# Out:
#    A  B  C  D
# 0  1  4  0  1
# 1  2  5  0  1
# 2  4  6  0  1
# 3  1  7  0  1
# 4  2  8  0  1
# 5  4  9  0  1

# %%
  from sklearn.feature_selection import VarianceThreshold
  var_thres = VarianceThreshold(threshold = 0)
  var_thres.fit(data)
# Out:
# VarianceThreshold(threshold=0)

# %%
var_thres.get_support()
# Out:
# array([ True,  True, False, False])

# %%
data.columns[var_thres.get_support()]
# Out:
# Index(['A', 'B'], dtype='object')

# %%
conts_col = [column for column in data.columns if column not in data.columns[var_thres.get_support()]]
print(len(conts_col))
# Out:
# 2

# %%
for feature in conts_col:
  print(feature)
# Out:
# C
# D

# %%
data.drop(conts_col,axis=1)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  4  6
# 3  1  7
# 4  2  8
# 5  4  9

# %% [markdown]
# On a Bigger DataSet

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d1e618f4-b986-4c9e-af6e-5c76d2420860" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1e618f4-b986-4c9e-af6e-5c76d2420860">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
df = pd.read_csv('train.csv',nrows = 10000)
df.shape
# Out:
# (10000, 371)

# %%
df.head()
# Out:
#    ID  var3  var15  ...  saldo_medio_var44_ult3          var38  TARGET
# 0   1     2     23  ...                     0.0   39205.170000       0
# 1   3     2     34  ...                     0.0   49278.030000       0
# 2   4     2     23  ...                     0.0   67333.770000       0
# 3   8     2     37  ...                     0.0   64007.970000       0
# 4  10     2     39  ...                     0.0  117310.979016       0
#
# [5 rows x 371 columns]

# %%
x = df.drop(labels=['TARGET'],axis = 1)
y = df.TARGET

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(
    df.drop(labels='TARGET',axis=1),
    df.TARGET,
    test_size = 0.3,
    random_state = 0
)
x_train.shape,x_test.shape
# Out:
# ((7000, 370), (3000, 370))

# %% [markdown]
# variance theshold is done on training dataset to avoid overfitting

# %%
var_thres = VarianceThreshold(threshold=0)
var_thres.fit(x_train)
# Out:
# VarianceThreshold(threshold=0)

# %%
sum(var_thres.get_support())
# Out:
# 284

# %%
len(x_train.columns[var_thres.get_support()])
# Out:
# 284

# %%
const_col = [column for column in x_train.columns if column not in x_train.columns[var_thres.get_support()]]
print(len(const_col))
# Out:
# 86

# %%
for feature in const_col:
  print(feature)
# Out:
# ind_var2_0
# ind_var2
# ind_var13_medio_0
# ind_var13_medio
# ind_var18_0
# ind_var18
# ind_var27_0
# ind_var28_0
# ind_var28
# ind_var27
# ind_var34_0
# ind_var34
# ind_var41
# ind_var46_0
# ind_var46
# num_var13_medio_0
# num_var13_medio
# num_var18_0
# num_var18
# num_var27_0
# num_var28_0
# num_var28
# num_var27
# num_var34_0
# num_var34
# num_var41
# num_var46_0
# num_var46
# saldo_var13_medio
# saldo_var18
# saldo_var28
# saldo_var27
# saldo_var34
# saldo_var41
# saldo_var46
# delta_imp_amort_var18_1y3
# delta_imp_amort_var34_1y3
# delta_imp_reemb_var17_1y3
# delta_imp_reemb_var33_1y3
# delta_imp_trasp_var17_out_1y3
# delta_imp_trasp_var33_out_1y3
# delta_num_reemb_var17_1y3
# delta_num_reemb_var33_1y3
# delta_num_trasp_var17_out_1y3
# delta_num_trasp_var33_out_1y3
# imp_amort_var18_hace3
# imp_amort_var18_ult1
# imp_amort_var34_hace3
# imp_amort_var34_ult1
# imp_var7_emit_ult1
# imp_reemb_var13_hace3
# imp_reemb_var17_hace3
# imp_reemb_var17_ult1
# imp_reemb_var33_hace3
# ...

# %%
x_train.drop(const_col,axis=1)
# Out:
#          ID  var3  ...  saldo_medio_var44_ult3      var38
# 7681  15431     2  ...                     0.0   37491.21
# 9031  18181     2  ...                     0.0  106685.94
# 3691   7411     2  ...                     0.0   66144.66
# 202     407     2  ...                     0.0   92121.36
# 5625  11280     2  ...                     0.0   74650.83
# ...     ...   ...  ...                     ...        ...
# 9225  18564     2  ...                     0.0  117547.89
# 4859   9723     2  ...                     0.0   71050.83
# 3264   6557     2  ...                     0.0  141069.33
# 9845  19796     2  ...                     0.0   86412.15
# 2732   5441     2  ...                     0.0   45985.68
#
# [7000 rows x 284 columns]

# %% [markdown]
# Corrleation

# %%
from sklearn.datasets import load_boston
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = load_boston()
df  =pd.DataFrame(data.data,columns = data.feature_names)
df['MEDV'] = data['target']

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
x = df.drop(labels='MEDV',axis = 1)
y = df['MEDV']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(
    x,
    y,
    test_size=0.3,
    random_state = 0
)
x_train.shape,x_test.shape
# Out:
# ((354, 13), (152, 13))

# %%
x_train.corr()
# Out:
#              CRIM        ZN     INDUS  ...   PTRATIO         B     LSTAT
# CRIM     1.000000 -0.196172  0.382073  ...  0.264780 -0.299525  0.439369
# ZN      -0.196172  1.000000 -0.529392  ... -0.392838  0.164641 -0.429178
# INDUS    0.382073 -0.529392  1.000000  ...  0.388353 -0.331638  0.603374
# CHAS    -0.049364 -0.063863  0.044224  ... -0.072683  0.069682 -0.059060
# NOX      0.416560 -0.523572  0.750218  ...  0.179046 -0.369445  0.577154
# RM      -0.188280  0.319260 -0.392969  ... -0.385526  0.157459 -0.623920
# AGE      0.329927 -0.583885  0.629257  ...  0.239729 -0.250416  0.606530
# DIS     -0.355840  0.658331 -0.686848  ... -0.176620  0.248376 -0.501780
# RAD      0.603880 -0.314833  0.578459  ...  0.437687 -0.415325  0.442783
# TAX      0.560570 -0.327834  0.719038  ...  0.447518 -0.412145  0.515905
# PTRATIO  0.264780 -0.392838  0.388353  ...  1.000000 -0.145638  0.387752
# B       -0.299525  0.164641 -0.331638  ... -0.145638  1.000000 -0.365338
# ...

# %%
import seaborn as sns
plt.figure(figsize=(12,10))
cor = x_train.corr()
sns.heatmap(cor,annot = True,cmap = plt.cm.CMRmap_r)
plt.show()

# %%
def correlation(df,threshold):
  col_corr = set() ###set of all names of correlated columns
  corr_matrix = df.corr()
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if abs(corr_matrix.iloc[i,j]) > threshold : ###abs is not so important
        colname = corr_matrix.columns[i]
        col_corr.add(colname)
  return col_corr

# %%
corr_features = correlation(x_train,0.7)
len(set(corr_features))
# Out:
# 4

# %%
corr_features
# Out:
# {'AGE', 'DIS', 'NOX', 'TAX'}

# %%
x_train.drop(corr_features,axis=1)
x_test.drop(corr_features,axis=1)
# Out:
#          CRIM   ZN  INDUS  CHAS     RM   RAD  PTRATIO       B  LSTAT
# 329   0.06724  0.0   3.24   0.0  6.333   4.0     16.9  375.21   7.34
# 371   9.23230  0.0  18.10   0.0  6.216  24.0     20.2  366.15   9.53
# 219   0.11425  0.0  13.89   1.0  6.373   5.0     16.4  393.74  10.50
# 403  24.80170  0.0  18.10   0.0  5.349  24.0     20.2  396.90  19.77
# 78    0.05646  0.0  12.83   0.0  6.232   5.0     18.7  386.40  12.34
# ..        ...  ...    ...   ...    ...   ...      ...     ...    ...
# 4     0.06905  0.0   2.18   0.0  7.147   3.0     18.7  396.90   5.33
# 428   7.36711  0.0  18.10   0.0  6.193  24.0     20.2   96.73  21.52
# 385  16.81180  0.0  18.10   0.0  5.277  24.0     20.2  396.90  30.81
# 308   0.49298  0.0   9.90   0.0  6.635   4.0     18.4  396.90   4.54
# 5     0.02985  0.0   2.18   0.0  6.430   3.0     18.7  394.12   5.21
#
# [152 rows x 9 columns]

# %% [markdown]
# Information Gain - Mutual Information

# %%
df = pd.read_csv('https://gist.githubusercontent.com/tijptjik/9408623/raw/b237fa5848349a14a14e5d4107dc7897c21951f5/wine.csv')
df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash  ...  Color.int   Hue    OD  Proline
# 0     1    14.23        1.71  2.43  ...       5.64  1.04  3.92     1065
# 1     1    13.20        1.78  2.14  ...       4.38  1.05  3.40     1050
# 2     1    13.16        2.36  2.67  ...       5.68  1.03  3.17     1185
# 3     1    14.37        1.95  2.50  ...       7.80  0.86  3.45     1480
# 4     1    13.24        2.59  2.87  ...       4.32  1.04  2.93      735
#
# [5 rows x 14 columns]

# %%
df.Wine.unique()
# Out:
# array([1, 2, 3])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Wine                  178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic.acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Acl                   178 non-null    float64
#  5   Mg                    178 non-null    int64
#  6   Phenols               178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid.phenols  178 non-null    float64
#  9   Proanth               178 non-null    float64
#  10  Color.int             178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  OD                    178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(
    df.drop(labels=['Wine'],axis=1),
    df.Wine,
    test_size=0.3,
    random_state = 0
)

# %%
x_train.head()
# Out:
#      Alcohol  Malic.acid   Ash   Acl  ...  Color.int   Hue    OD  Proline
# 22     13.71        1.86  2.36  16.6  ...       3.80  1.11  4.00     1035
# 108    12.22        1.29  1.94  19.0  ...       2.70  0.86  3.02      312
# 175    13.27        4.28  2.26  20.0  ...      10.20  0.59  1.56      835
# 145    13.16        3.57  2.15  21.0  ...       4.00  0.60  1.68      830
# 71     13.86        1.51  2.67  25.0  ...       3.38  1.36  3.16      410
#
# [5 rows x 13 columns]

# %%
 from sklearn.feature_selection import mutual_info_classif
 ###determine the mutual information
 mutual_info = mutual_info_classif(x_train,y_train)
 mutual_info
# Out:
# array([0.41888735, 0.29941215, 0.16536344, 0.24806402, 0.16090716,
#        0.48499586, 0.71563144, 0.11041153, 0.25586973, 0.6127796 ,
#        0.54317304, 0.54688822, 0.52992999])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = x_train.columns
mutual_info.sort_values(ascending = False)
# Out:
# Flavanoids              0.715631
# Color.int               0.612780
# OD                      0.546888
# Hue                     0.543173
# Proline                 0.529930
# Phenols                 0.484996
# Alcohol                 0.418887
# Malic.acid              0.299412
# Proanth                 0.255870
# Acl                     0.248064
# Ash                     0.165363
# Mg                      0.160907
# Nonflavanoid.phenols    0.110412
# dtype: float64

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20,8))

# %%
from sklearn.feature_selection import SelectKBest ###for using top best features

# %%
sel_five_cols = SelectKBest(mutual_info_classif,k=5)
sel_five_cols.fit(x_train,y_train)
x_train.columns[sel_five_cols.get_support()]
# Out:
# Index(['Flavanoids', 'Color.int', 'Hue', 'OD', 'Proline'], dtype='object')

# %% [markdown]
# Mutual Information - Regression Problem Statement

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-27c24861-9834-47e6-8f89-8cc18e56363c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27c24861-9834-47e6-8f89-8cc18e56363c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv
# ...

# %%
housing_df = pd.read_csv('train.csv')

# %%
housing_df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
housing_df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
numeric_list = ['int16','int32','int64','float16','float32','float64']
numerical_cols = list(housing_df.select_dtypes(include=numeric_list).columns)

# %%
housing_df = housing_df[numerical_cols]
housing_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  ...  MiscVal  MoSold  YrSold  SalePrice
# 0   1          60         65.0     8450  ...        0       2    2008     208500
# 1   2          20         80.0     9600  ...        0       5    2007     181500
# 2   3          60         68.0    11250  ...        0       9    2008     223500
# 3   4          70         60.0     9550  ...        0       2    2006     140000
# 4   5          60         84.0    14260  ...        0      12    2008     250000
#
# [5 rows x 38 columns]

# %%
numerical_cols
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
housing_df = housing_df.drop(labels=housing_df.columns[0],axis=1)
housing_df.head()
# Out:
#    LotFrontage  LotArea  OverallQual  ...  MoSold  YrSold  SalePrice
# 0         65.0     8450            7  ...       2    2008     208500
# 1         80.0     9600            6  ...       5    2007     181500
# 2         68.0    11250            7  ...       9    2008     223500
# 3         60.0     9550            7  ...       2    2006     140000
# 4         84.0    14260            8  ...      12    2008     250000
#
# [5 rows x 36 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(
    housing_df.drop(labels=['SalePrice'],axis=1),
    housing_df['SalePrice'],
    test_size=0.3,
    random_state=0
)

# %%
x_train
# Out:
#       LotFrontage  LotArea  OverallQual  ...  MiscVal  MoSold  YrSold
# 64            NaN     9375            7  ...        0       2    2009
# 682           NaN     2887            6  ...        0      11    2008
# 960          50.0     7207            5  ...        0       2    2010
# 1384         60.0     9060            6  ...        0      10    2009
# 1100         60.0     8400            2  ...        0       1    2009
# ...           ...      ...          ...  ...      ...     ...     ...
# 763          82.0     9430            8  ...        0       7    2009
# 835          60.0     9600            4  ...        0       2    2010
# 1216         68.0     8930            6  ...        0       4    2010
# 559           NaN     3196            7  ...        0      10    2006
# 684          58.0    16770            7  ...        0       6    2010
#
# [1022 rows x 35 columns]

# %%
x_train.isnull().sum()
# Out:
# LotFrontage      189
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         5
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       54
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %%
from sklearn.feature_selection import mutual_info_regression
###deteminen the mutual information
mutual_info = mutual_info_regression(x_train.fillna(0),y_train)
mutual_info
# Out:
# array([0.20994526, 0.16568435, 0.5332006 , 0.09756986, 0.35040507,
#        0.23143977, 0.0986651 , 0.15906066, 0.01163672, 0.11339707,
#        0.38356705, 0.31181061, 0.22819599, 0.00227984, 0.48011597,
#        0.02227879, 0.        , 0.25957891, 0.07784454, 0.0317742 ,
#        0.03040532, 0.1907475 , 0.1776993 , 0.26533912, 0.37152584,
#        0.36920476, 0.07127523, 0.17312419, 0.02904234, 0.        ,
#        0.02567974, 0.        , 0.        , 0.        , 0.01198232])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = x_train.columns
mutual_info.sort_values(ascending = False)
# Out:
# OverallQual      0.533201
# GrLivArea        0.480116
# TotalBsmtSF      0.383567
# GarageCars       0.371526
# GarageArea       0.369205
# YearBuilt        0.350405
# 1stFlrSF         0.311811
# GarageYrBlt      0.265339
# FullBath         0.259579
# YearRemodAdd     0.231440
# 2ndFlrSF         0.228196
# LotFrontage      0.209945
# TotRmsAbvGrd     0.190748
# Fireplaces       0.177699
# OpenPorchSF      0.173124
# LotArea          0.165684
# BsmtFinSF1       0.159061
# BsmtUnfSF        0.113397
# MasVnrArea       0.098665
# OverallCond      0.097570
# HalfBath         0.077845
# WoodDeckSF       0.071275
# BedroomAbvGr     0.031774
# KitchenAbvGr     0.030405
# EnclosedPorch    0.029042
# ScreenPorch      0.025680
# BsmtFullBath     0.022279
# YrSold           0.011982
# BsmtFinSF2       0.011637
# LowQualFinSF     0.002280
# 3SsnPorch        0.000000
# PoolArea         0.000000
# BsmtHalfBath     0.000000
# MiscVal          0.000000
# MoSold           0.000000
# dtype: float64

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize = (15,5))

# %%
from sklearn.feature_selection import SelectPercentile

# %%
selected_top_columns = SelectPercentile(mutual_info_regression,percentile=20)
selected_top_columns.fit(x_train.fillna(0),y_train)
x_train.columns[selected_top_columns.get_support()]
# Out:
# Index(['OverallQual', 'YearBuilt', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea',
#        'GarageCars', 'GarageArea'],
#       dtype='object')

# %% [markdown]
# Fisher Score - Chisquare Test For Feature Selection

# %%
import seaborn as sns
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
###['sex','embarked','alone','pclass,'survived']
df = df[['sex','embarked','alone','pclass','survived']]
df.head()
# Out:
#       sex embarked  alone  pclass  survived
# 0    male        S  False       3         0
# 1  female        C  False       1         1
# 2  female        S   True       3         1
# 3  female        S  False       1         1
# 4    male        S   True       3         0

# %%
###label encoding for categorical columns
import numpy as np
df.sex = np.where(df.sex=='male',1,0)
ordinal_encoding = {k:i for i,k in enumerate(df.embarked.unique(),0)}
df.embarked = df.embarked.map(ordinal_encoding)

# %%
df.head()
# Out:
#    sex  embarked  alone  pclass  survived
# 0    1         0  False       3         0
# 1    0         1  False       1         1
# 2    0         0   True       3         1
# 3    0         0  False       1         1
# 4    1         0   True       3         0

# %%
df.alone = np.where(df.alone==False,0,1)

# %%
df.head()
# Out:
#    sex  embarked  alone  pclass  survived
# 0    1         0      0       3         0
# 1    0         1      0       1         1
# 2    0         0      1       3         1
# 3    0         0      0       1         1
# 4    1         0      1       3         0

# %%
###train test split is usually done to avoid overfitting
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(
    df[['sex','embarked','alone','pclass']],
    df['survived'],
    test_size=0.3,
    random_state=0
)

# %%
x_train.head()
# Out:
#      sex  embarked  alone  pclass
# 857    1         0      1       1
# 52     0         1      0       1
# 386    1         0      0       3
# 124    1         0      0       1
# 578    0         1      0       3

# %%
###perform chi-square test return fscore(higher) and the p values(lower)
from sklearn.feature_selection import chi2
f_p_values = chi2(x_train,y_train)

# %%
f_p_values
# Out:
# (array([63.55447864, 11.83961845,  9.03328564, 21.61080949]),
#  array([1.55992554e-15, 5.79837058e-04, 2.65107556e-03, 3.33964360e-06]))

# %%
import pandas as pd
p_values = pd.Series(f_p_values[1])
p_values.index = x_train.columns
p_values
# Out:
# sex         1.559926e-15
# embarked    5.798371e-04
# alone       2.651076e-03
# pclass      3.339644e-06
# dtype: float64

# %%
p_values.sort_index(ascending=False) ###sex columns is the most important feature
# Out:
# sex         1.559926e-15
# pclass      3.339644e-06
# embarked    5.798371e-04
# alone       2.651076e-03
# dtype: float64
